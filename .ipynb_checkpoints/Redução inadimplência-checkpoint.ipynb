# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
dd = pd.read_csv('2866.dat', sep='\t')
dd
# Out:
#        2    48  2.1     1    5951  2.2    3  2.3  1.1  3.1  2.4    22  3.2  \
# 0      3  12.0  1.0   2.0  2096.0  2.0    4  2.0  4.0  3.0    3  49.0  3.0
# 1      4  42.0  2.0   3.0  7882.0  2.0    4  2.0  4.0  4.0    4  45.0  3.0
# 2      5  24.0  3.0   4.0  4870.0  2.0    3  3.0  4.0  3.0    4  53.0  3.0
# 3      6  36.0  2.0   2.0  9055.0  1.0    3  2.0  4.0  3.0    4  35.0  3.0
# 4      7  24.0  2.0   3.0  2835.0  3.0    2  3.0  4.0  3.0    4  53.0  3.0
# ..   ...   ...  ...   ...     ...  ...  ...  ...  ...  ...  ...   ...  ...
# 995  834  24.0  2.0   1.0  5084.0  1.0    2  2.0  1.0  3.0    4  42.0  3.0
# 996  234  18.0  0.0   1.0   866.0  2.0    3  4.0  3.0  4.0    2  25.0  3.0
# 997  474   6.0  0.0  10.0  1238.0  1.0    5  4.0  4.0  3.0    4  36.0  3.0
# 998  565  24.0  0.0   6.0  4712.0  1.0    3  4.0  4.0  3.0    2  37.0  1.0
# 999   \.   NaN  NaN   NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
#      1.2  1.3      4  1.4    0  0.1  0.2
# ...

# %%
nomes = ['ID','Duração','Historico Crédito', 'Propósito', 'Valor', 'Investimentos', 'Emprego', 'Tempo Parcelamento', 'Estado Civil', 'Fiador Terceiros', 'Residencia dês de', 'Idade', 'Outros Financiamentos', 'Habitação', 'Emprestimo Existente', 'Profissão', 'Dependentes', 'Sócio Empresa', 'Estrangeiro', 'Status']

dd.columns = nomes

# %%
dd.drop(999, inplace=True)
dd
# Out:
#       ID  Duração  Historico Crédito  Propósito   Valor  Investimentos  \
# 0      3     12.0                1.0        2.0  2096.0            2.0
# 1      4     42.0                2.0        3.0  7882.0            2.0
# 2      5     24.0                3.0        4.0  4870.0            2.0
# 3      6     36.0                2.0        2.0  9055.0            1.0
# 4      7     24.0                2.0        3.0  2835.0            3.0
# ..   ...      ...                ...        ...     ...            ...
# 994  505     24.0                2.0        4.0  1207.0            2.0
# 995  834     24.0                2.0        1.0  5084.0            1.0
# 996  234     18.0                0.0        1.0   866.0            2.0
# 997  474      6.0                0.0       10.0  1238.0            1.0
# 998  565     24.0                0.0        6.0  4712.0            1.0
#
#     Emprego  Tempo Parcelamento  Estado Civil  Fiador Terceiros  \
# ...

# %%
agrupado = dd.groupby(['Emprego']).size()
agrupado
# Out:
# Emprego
# 1     171
# 2     247
# 3     337
# 4     172
# 5      62
# \N     10
# dtype: int64

# %%
agrupado = dd.groupby(['Residencia dês de']).size()
agrupado
# Out:
# Residencia dês de
# 1     129
# 2     307
# 3     147
# 4     409
# \N      7
# dtype: int64

# %%
agrupado = dd.groupby(['Habitação']).size()
agrupado
# Out:
# Habitação
# 1     708
# 2     107
# 3     175
# \N      9
# dtype: int64

# %%
agrupado = dd.groupby(['Profissão']).size()
agrupado
# Out:
# Profissão
# 1.0      147
# 2.0       22
# 3.0      197
# 4.0      624
# 999.0      9
# dtype: int64

# %%
dd.loc[(dd['Emprego'] != '1') & (dd['Emprego'] != '2') & (dd['Emprego'] != '3') & (dd['Emprego'] != '4') & (dd['Emprego'] != '5'), 'Emprego'] = 3

# %%
agrupado = dd.groupby(['Emprego']).size()
agrupado
# Out:
# Emprego
# 3     10
# 1    171
# 2    247
# 3    337
# 4    172
# 5     62
# dtype: int64

# %%
dd.loc[(dd['Residencia dês de'] != '1') & (dd['Residencia dês de'] != '2') & (dd['Residencia dês de'] != '3') & (dd['Residencia dês de'] != '4'), 'Residencia dês de'] = 4

# %%
agrupado = dd.groupby(['Residencia dês de']).size()
agrupado
# Out:
# Residencia dês de
# 4      7
# 1    129
# 2    307
# 3    147
# 4    409
# dtype: int64

# %%
dd.loc[(dd['Habitação'] != '1') & (dd['Habitação'] != '2') & (dd['Habitação'] != '3'), 'Habitação'] = 1

# %%
agrupado = dd.groupby(['Habitação']).size()
agrupado
# Out:
# Habitação
# 1      9
# 1    708
# 2    107
# 3    175
# dtype: int64

# %%
dd.loc[(dd['Profissão'] > 4), 'Profissão'] = 4

# %%
agrupado = dd.groupby(['Profissão']).size()
agrupado
# Out:
# Profissão
# 1.0    147
# 2.0     22
# 3.0    197
# 4.0    633
# dtype: int64

# %%
x = dd.iloc[:,1:19].values
y = dd.iloc[:,19]

# %%
model = LogisticRegression(max_iter=3000)

# %%
from sklearn.feature_selection import RFE

# %%
rfe = RFE(model, 12)
# Out:
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_features_to_select=12 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
fit = rfe.fit(x,y)

# %%
print('Número de features: {}'.format(fit.n_features_))
# Out:
# Número de features: 12

# %%
cols = fit.get_support(indices=True)
cols = cols +1
dd.iloc[:,cols]
# Out:
#      Historico Crédito Emprego  Tempo Parcelamento  Estado Civil  \
# 0                  1.0       4                 2.0           4.0
# 1                  2.0       4                 2.0           4.0
# 2                  3.0       3                 3.0           4.0
# 3                  2.0       3                 2.0           4.0
# 4                  2.0       2                 3.0           4.0
# ..                 ...     ...                 ...           ...
# 994                2.0       1                 4.0           1.0
# 995                2.0       2                 2.0           1.0
# 996                0.0       3                 4.0           3.0
# 997                0.0       5                 4.0           4.0
# 998                0.0       3                 4.0           4.0
#
#      Fiador Terceiros Residencia dês de  Outros Financiamentos Habitação  \
# 0                 3.0                 3                    3.0         1
# ...

# %%
features = fit.transform(x)
print(features)
# Out:
# [[1.0 '4' 2.0 ... 2.0 0.0 0.0]
#  [2.0 '4' 2.0 ... 2.0 0.0 0.0]
#  [3.0 '3' 3.0 ... 2.0 0.0 0.0]
#  ...
#  [0.0 '3' 4.0 ... 1.0 0.0 0.0]
#  [0.0 '5' 4.0 ... 2.0 1.0 0.0]
#  [0.0 '3' 4.0 ... 1.0 1.0 0.0]]

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2 , random_state=0)

# %%
sc = StandardScaler()
x_trainD = sc.fit_transform(x_train)
x_testD = sc.fit_transform(x_test)
x_test
# Out:
# array([[24.0, 5.0, 4.0, ..., 1.0, 0.0, 0.0],
#        [24.0, 2.0, 9.0, ..., 1.0, 1.0, 0.0],
#        [16.0, 1.0, 4.0, ..., 1.0, 1.0, 0.0],
#        ...,
#        [18.0, 2.0, 1.0, ..., 1.0, 0.0, 0.0],
#        [12.0, 2.0, 2.0, ..., 2.0, 0.0, 0.0],
#        [12.0, 2.0, 3.0, ..., 1.0, 1.0, 0.0]], dtype=object)

# %%
classifier = Sequential()
classifier.add(Dense(units= 8, kernel_initializer= 'uniform', activation= 'relu', input_dim= 18))
classifier.add(Dense(units= 8, kernel_initializer= 'uniform', activation= 'relu'))
classifier.add(Dense(units= 4, kernel_initializer= 'uniform', activation= 'relu'))
classifier.add(Dense(units= 4, kernel_initializer= 'uniform', activation= 'relu'))
classifier.add(Dense(units= 2, kernel_initializer= 'uniform', activation= 'relu'))
classifier.add(Dense(units= 2, kernel_initializer= 'uniform', activation= 'relu'))
classifier.add(Dense(units= 1, kernel_initializer= 'uniform', activation= 'sigmoid'))
classifier.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics= ['accuracy'])
classifier.fit(x_trainD, y_train, batch_size= 10, epochs= 10)
# Out:
# Epoch 1/10
# 80/80 [==============================] - 2s 4ms/step - loss: 0.6864 - accuracy: 0.6984
# Epoch 2/10
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6712 - accuracy: 0.7059
# Epoch 3/10
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6522 - accuracy: 0.7059
# Epoch 4/10
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6315 - accuracy: 0.7059
# Epoch 5/10
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6156 - accuracy: 0.7059
# Epoch 6/10
# 80/80 [==============================] - 0s 4ms/step - loss: 0.6090 - accuracy: 0.7059
# Epoch 7/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.6066 - accuracy: 0.7059
# Epoch 8/10
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6060 - accuracy: 0.7059
# Epoch 9/10
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6062 - accuracy: 0.7059
# Epoch 10/10
# ...

# %%
y_pred = classifier.predict(x_testD)
y_pred = (y_pred > 0.5)
y_pred
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
# ...

# %%
confusao = confusion_matrix(y_test, y_pred)
confusao
# Out:
# array([[  0,  64],
#        [  0, 136]], dtype=int64)

# %%
taxa_acerto = accuracy_score(y_test, y_pred)
taxa_erro = 1 - taxa_acerto
taxa_acerto
# Out:
# 0.68

# %%
floresta = RandomForestClassifier(n_estimators= 300)
floresta.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=300)

# %%
previsoes = floresta.predict(x_test)
taxa_acerto = accuracy_score(y_test, previsoes)
taxa_acerto
# Out:
# 0.75

# %% [markdown]
# Após o uso de deep learning e ramdom forest foi notado que nesta primeira abordagem o modelo random forest atingiu o objetivo proposto de 75% de acerto no modelo.
